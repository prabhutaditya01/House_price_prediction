# %%
# !pip install seaborn
# !pip install scikit-learn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ds=pd.read_csv('dataset_houseprice.csv')

# %%
ds.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
ds.dtypes
# Out:
# date              object
# price            float64
# bedrooms         float64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# street            object
# city              object
# statezip          object
# country           object
# dtype: object

# %%
ds.empty
# Out:
# False

# %%
ds1=ds.drop(["date","country","street","statezip","city"],axis=1)

# %%
ds1.dropna()
# Out:
#              price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0     3.130000e+05       3.0       1.50         1340      7912     1.5
# 1     2.384000e+06       5.0       2.50         3650      9050     2.0
# 2     3.420000e+05       3.0       2.00         1930     11947     1.0
# 3     4.200000e+05       3.0       2.25         2000      8030     1.0
# 4     5.500000e+05       4.0       2.50         1940     10500     1.0
# ...            ...       ...        ...          ...       ...     ...
# 4595  3.081667e+05       3.0       1.75         1510      6360     1.0
# 4596  5.343333e+05       3.0       2.50         1460      7573     2.0
# 4597  4.169042e+05       3.0       2.50         3010      7014     2.0
# 4598  2.034000e+05       4.0       2.00         2090      6630     1.0
# 4599  2.206000e+05       3.0       2.50         1490      8102     2.0
#
#       waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# ...

# %%
ds1
# Out:
#              price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0     3.130000e+05       3.0       1.50         1340      7912     1.5
# 1     2.384000e+06       5.0       2.50         3650      9050     2.0
# 2     3.420000e+05       3.0       2.00         1930     11947     1.0
# 3     4.200000e+05       3.0       2.25         2000      8030     1.0
# 4     5.500000e+05       4.0       2.50         1940     10500     1.0
# ...            ...       ...        ...          ...       ...     ...
# 4595  3.081667e+05       3.0       1.75         1510      6360     1.0
# 4596  5.343333e+05       3.0       2.50         1460      7573     2.0
# 4597  4.169042e+05       3.0       2.50         3010      7014     2.0
# 4598  2.034000e+05       4.0       2.00         2090      6630     1.0
# 4599  2.206000e+05       3.0       2.50         1490      8102     2.0
#
#       waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# ...

# %%
Y=ds1.iloc[:,0]
Y
# Out:
# 0       3.130000e+05
# 1       2.384000e+06
# 2       3.420000e+05
# 3       4.200000e+05
# 4       5.500000e+05
#             ...
# 4595    3.081667e+05
# 4596    5.343333e+05
# 4597    4.169042e+05
# 4598    2.034000e+05
# 4599    2.206000e+05
# Name: price, Length: 4600, dtype: float64

# %%
X=ds1.iloc[:,-1]
X
# Out:
# 0       Shoreline
# 1         Seattle
# 2            Kent
# 3        Bellevue
# 4         Redmond
#           ...
# 4595      Seattle
# 4596     Bellevue
# 4597       Renton
# 4598      Seattle
# 4599    Covington
# Name: city, Length: 4600, dtype: object

# %%
plt.figure(figsize=(55,20))
plt.scatter(X,Y,cmap="viridis")

# %%
ds1.corr()
# Out:
#                   price  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# price          1.000000  0.200336   0.327110     0.430322  0.050451  0.151461
# bedrooms       0.200336  1.000000   0.545920     0.594876  0.068819  0.177895
# bathrooms      0.327110  0.545920   1.000000     0.760952  0.107837  0.486428
# sqft_living    0.430322  0.594876   0.760952     1.000000  0.210642  0.344512
# sqft_lot       0.050451  0.068819   0.107837     0.210642  1.000000  0.003750
# floors         0.151461  0.177895   0.486428     0.344512  0.003750  1.000000
# waterfront     0.135648 -0.003483   0.076232     0.117643  0.017241  0.022024
# view           0.228504  0.111028   0.211960     0.311103  0.073907  0.031211
# condition      0.034915  0.025080  -0.119994    -0.062560  0.000558 -0.275013
# sqft_above     0.367570  0.484705   0.689918     0.876592  0.216455  0.522814
# sqft_basement  0.210427  0.334165   0.298020     0.446417  0.034842 -0.255510
# ...

# %%
ds2=pd.get_dummies(ds1)
columns=ds2.columns
ds2
# Out:
#              price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0     3.130000e+05       3.0       1.50         1340      7912     1.5
# 1     2.384000e+06       5.0       2.50         3650      9050     2.0
# 2     3.420000e+05       3.0       2.00         1930     11947     1.0
# 3     4.200000e+05       3.0       2.25         2000      8030     1.0
# 4     5.500000e+05       4.0       2.50         1940     10500     1.0
# ...            ...       ...        ...          ...       ...     ...
# 4595  3.081667e+05       3.0       1.75         1510      6360     1.0
# 4596  5.343333e+05       3.0       2.50         1460      7573     2.0
# 4597  4.169042e+05       3.0       2.50         3010      7014     2.0
# 4598  2.034000e+05       4.0       2.00         2090      6630     1.0
# 4599  2.206000e+05       3.0       2.50         1490      8102     2.0
#
#       waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# ...

# %%
#creating heat map using correlation

# %%
plt.figure(figsize=(15,10))
sns.heatmap(ds1.corr(),annot=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#feature scaling starts from here

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn import preprocessing

# %%
scaler=preprocessing.MinMaxScaler(feature_range=(0,1))
normal=pd.DataFrame(scaler.fit_transform(ds2),columns=columns)
normal.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  0.011771  0.333333    0.18750     0.073652  0.006775     0.2         0.0
# 1  0.089658  0.555556    0.31250     0.249051  0.007835     0.4         0.0
# 2  0.012862  0.333333    0.25000     0.118451  0.010534     0.0         0.0
# 3  0.015795  0.333333    0.28125     0.123766  0.006885     0.0         0.0
# 4  0.020684  0.444444    0.31250     0.119210  0.009186     0.0         0.0
#
#    view  condition  sqft_above  sqft_basement  yr_built  yr_renovated
# 0   0.0       0.50    0.107301       0.000000  0.482456      0.995531
# 1   1.0       1.00    0.331858       0.058091  0.184211      0.000000
# 2   0.0       0.75    0.172566       0.000000  0.578947      0.000000
# 3   0.0       0.75    0.069690       0.207469  0.552632      0.000000
# 4   0.0       0.75    0.085177       0.165975  0.666667      0.989076

# %%
#Bifurcating Dependent and independent variables

# %%
from sklearn.model_selection import train_test_split
x=normal.drop("price",axis=1)
y=pd.DataFrame(normal["price"])
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=43)

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics
model=LinearRegression()
model.fit(x_train, y_train)
y_pred=model.predict(x_test)
print("mean absolute error:" ,metrics.mean_absolute_error(y_test,y_pred))
print("mean squared error:", metrics.mean_squared_error(y_test,y_pred))
print("root mean squared error:" ,np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
print("r2 score:" ,metrics.r2_score(y_test,y_pred))
# Out:
# mean absolute error: 0.006008260395872038
# mean squared error: 0.00010638292718349369
# root mean squared error: 0.010314209964097768
# r2 score: 0.5207636718458752

# %%
#calculating VIF

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
x1=ds1[["price","bedrooms","bathrooms","sqft_living","sqft_lot","floors","waterfront","view","condition","sqft_above","sqft_basement","yr_built","yr_renovated"]]

# %%
#VIF dataframe
vif_data=pd.DataFrame()
vif_data["feature"]=x1.columns

# %%
#calculating vif

# %%
vif_data["VIF"]=[variance_inflation_factor(x1.values,i)
                         for i in range(len(x1.columns))]
print(vif_data)
# Out:
#           feature           VIF
# 0           price      2.479703
# 1        bedrooms     25.156002
# 2       bathrooms     25.909954
# 3     sqft_living  12061.717999
# 4        sqft_lot      1.261645
# 5          floors     16.608776
# 6      waterfront      1.167510
# 7            view      1.470887
# 8       condition     30.933783
# 9      sqft_above   8965.328109
# 10  sqft_basement    684.044294
# 11       yr_built     64.679996
# 12   yr_renovated      1.934294

# %%
ds1.drop("sqft_living",axis=1,inplace=True)

# %%
ds1
# Out:
#              price  bedrooms  bathrooms  sqft_lot  floors  waterfront  view  \
# 0     3.130000e+05       3.0       1.50      7912     1.5           0     0
# 1     2.384000e+06       5.0       2.50      9050     2.0           0     4
# 2     3.420000e+05       3.0       2.00     11947     1.0           0     0
# 3     4.200000e+05       3.0       2.25      8030     1.0           0     0
# 4     5.500000e+05       4.0       2.50     10500     1.0           0     0
# ...            ...       ...        ...       ...     ...         ...   ...
# 4595  3.081667e+05       3.0       1.75      6360     1.0           0     0
# 4596  5.343333e+05       3.0       2.50      7573     2.0           0     0
# 4597  4.169042e+05       3.0       2.50      7014     2.0           0     0
# 4598  2.034000e+05       4.0       2.00      6630     1.0           0     0
# 4599  2.206000e+05       3.0       2.50      8102     2.0           0     0
#
# ...

# %%
plt.scatter(y_test,y_pred)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from sklearn.model_selection import train_test_split
x=normal.drop("price",axis=1)
y=pd.DataFrame(normal["price"])
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=43)

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics
model=LinearRegression()
model.fit(x_train, y_train)
y_pred=model.predict(x_test)
print("mean absolute error:" ,metrics.mean_absolute_error(y_test,y_pred))
print("mean squared error:", metrics.mean_squared_error(y_test,y_pred))
print("root mean squared error:" ,np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
print("r2 score:" ,metrics.r2_score(y_test,y_pred))
# Out:
# mean absolute error: 0.006008260395872038
# mean squared error: 0.00010638292718349369
# root mean squared error: 0.010314209964097768
# r2 score: 0.5207636718458752

# %%
plt.scatter(y_test,y_pred)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
